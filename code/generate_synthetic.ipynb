# %% [markdown]
# # Notebook to show how to generate synthetic networks by using the proposed benchmark

# %%
import synthetic

# %% [markdown]
# #### ReciprocityMMSBM_joints

# %%
N = 250  # number of nodes
K = 2  # number of communities
avg_degree = 20  # average degree
eta = 50  # pair interaction parameter

label = 'synthetic_data'
out_folder = '../data/input/'
output_net = True
show_details = True
show_plots = True

# %%
syn = synthetic.ReciprocityMMSBM_joints(N=N, K=K, avg_degree=avg_degree, eta=eta, label=label, out_folder=out_folder, 
                                        output_net=output_net, show_details=show_details, show_plots=show_plots)
# Out:
# /Users/mcontisciani/Projects/SourceTree/_Public/JointCRep/code/synthetic.py:351: UserWarning: is_sparse parameter was not set. Defaulting to is_sparse=True
#   warnings.warn(msg)
# /Users/mcontisciani/Projects/SourceTree/_Public/JointCRep/code/synthetic.py:379: UserWarning: perc_overlapping parameter was not set. Defaulting to perc_overlapping=0.2
#   warnings.warn(msg)
# /Users/mcontisciani/Projects/SourceTree/_Public/JointCRep/code/synthetic.py:393: UserWarning: correlation_u_v parameter for overlapping communities was not set. Defaulting to corr=0.0
#   warnings.warn(msg)
# /Users/mcontisciani/Projects/SourceTree/_Public/JointCRep/code/synthetic.py:401: UserWarning: alpha parameter of Dirichlet distribution was not set. Defaulting to alpha=[0.1, 0.1]
#   warnings.warn(msg)
# /Users/mcontisciani/Projects/SourceTree/_Public/JointCRep/code/synthetic.py:424: UserWarning: structure parameter was not set. Defaulting to structure=['assortative']
#   warnings.warn(msg)
# Parameters saved in: ../data/input/gt_synthetic_data.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../data/input/synthetic_data.dat
# Number of nodes = 250
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 2512 - <k> = 20.096
# Sparsity [0] = 0.04
# Reciprocity (networkX) = 0.581
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.41
